# %% [markdown]
# # 집나간 정신과 마음 되찾는 주식거래 자동화 시스템

# %% [markdown]
# ### 파이썬을 탄 개미가 할 수 있는 것
#
# <p>
# 증권사 API와 카카오 API를 이용한 주식거래 자동화 시스템 개발
# </p>
# <BR>
# <p>
# <ul>
# <li>
# 사용자가 주식 종목의 '일봉 데이터'를 증권사 API를 통해 요청
# </li>
# </ul>
# </p>
#
# ![image.png](attachment:image.png)
